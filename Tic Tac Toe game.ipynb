# %%
# my tic tac toe game
#jst run the code to play the game
def playboard(board):
    print(board[8]+'|'+board[7]+'|'+board[6] +    "positions->8|7|6")
    print("-|-|-"  + "           5|4|3")
    print(board[5]+'|'+board[4]+'|'+board[3] +     "           0|1|2")
    print('-|-|-')
    print(board[0]+'|'+board[1]+'|'+board[2])


def players():
    player1='abc'
    while player1!='X' and player1!='O':
        player1=input("Choose yourself as ....(X or Y)  ")
        if player1=="X":
            player2="O"
        else:
            player2="X"
    return (player1,player2)


def game():
    choice="Y"
    while choice=="Y":
       

        board=[" "]*10
        player1,player2=players()
        print("PLAYER 1 IS....." + player1)
        print("PLAYER 2 IS....." + player2)
        if player1=="X":
            t=0
        else:
            t=1
        game="start"
        
        while game!="over":
            if t==0:
                position=int(input("player1 Enter the input of position "))
                board[position]="X"  
                playboard(board)
                t=1
                if board[0]=="X" and board[1]=="X" and board[2]=="X":
                    if board[0]==board[1]==board[2]:
                        print("you Won")
                        choice=input("do you wana play the game  .. enter (Y or N)")
                        game="over"
                elif board[5]=="X" and board[4]=="X" and board[3]=="X":
                    if board[5]==board[4]==board[3]:
                        print("you Won")
                        choice=input("do you wana play the game  .. enter (Y or N)")
                        game="over"
                elif board[6]=="X" and board[7]=="X" and board[8]=="X":
                    if board[6]==board[7]==board[8]:
                        print("you Won")
                        choice=input("do you wana play the game  .. enter (Y or N)")
                        game="over"
                elif board[1]=="X" and board[4]=="X" and board[7]=="X":
                    if board[1]==board[4]==board[7]:
                        print("you Won")
                        choice=input("do you wana play the game  .. enter (Y or N)")
                        game="over"
                elif board[2]=="X" and board[3]=="X" and board[6]=="X": 
                    if board[2]==board[3]==board[6]:
                        print("You Won baby")
                        choice=input("do you wana play the game  .. enter (Y or N)")
                        game="over"
                elif board[2]=="X" and board[4]=="X" and board[8]=="X": 
                    if board[2]==board[4]==board[8]:
                        print("You Won baby")
                        choice=input("do you wana play the game  .. enter (Y or N)")
                        game="over"
                elif board[0]=="X" and board[4]=="X" and board[6]=="X": 
                    if board[0]==board[4]==board[6]:
                        print("You Won baby")
                        choice=input("do you wana play the game  .. enter (Y or N)")
                        game="over"
                else:
                        pass
            
                    
            elif t==1:
                position=int(input("player2 Enter the input of position "))
                m=1 
                board[position]="O"
                playboard(board)
                t=0
                if board[0]=="O" and board[1]=="O" and board[2]=="O":
                    if board[0]==board[1]==board[2]:
                        print("you Won")
                        choice=input("do you wana play the game  .. enter (Y or N)")
                        game="over"
                elif board[5]=="O" and board[3]=="O" and board[4]=="O":
                    if board[5]==board[3]==board[4]:
                        print("you Won")
                        choice=input("do you wana play the game  .. enter (Y or N)")
                        game="over"
                elif board[6]=="O" and board[7]=="O" and board[8]=="O":
                    if board[6]==board[7]==board[8]:
                        print("you Won")
                        choice=input("do you wana play the game  .. enter (Y or N)")
                        game="over"
                elif board[0]=="O" and board[3]=="O" and board[7]=="O":
                    if board[0]==board[3]==board[7]:
                        print("you Won")
                        choice=input("do you wana play the game  .. enter (Y or N)")
                        game="over"
                elif board[2]=="O" and board[3]=="O" and board[6]=="O": 
                    if board[2]==board[3]==board[6]:
                        print("You Won baby")
                        choice=input("do you wana play the game  .. enter (Y or N)")
                        game="over"
                elif board[0]=="O" and board[4]=="O" and board[6]=="O": 
                    if board[0]==board[4]==board[6]:
                        print("You Won baby")
                        choice=input("do you wana play the game  .. enter (Y or N)")
                        game="over"
                elif board[2]=="O" and board[4]=="O" and board[8]=="O": 
                    if board[2]==board[4]==board[8]:
                        print("You Won baby")
                        choice=input("do you wana play the game  .. enter (Y or N)")
                        game="over"
                else:
                        pass
                    
game()
# Out:
# Choose yourself as ....(X or Y)  x
# Choose yourself as ....(X or Y)  X
# PLAYER 1 IS.....X
# PLAYER 2 IS.....O

# %%
game()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4a8413945148> in <module>
# ----> 1 game()
#
# NameError: name 'game' is not defined
